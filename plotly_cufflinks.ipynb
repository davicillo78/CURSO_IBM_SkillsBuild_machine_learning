# %% [markdown]
# ### Plotly y Cufflinks ###
# Plotly es una librería para visualizaciones interactivas.
# Cufflinks ayuda a conectar Plotly con Pandas

# %%
import pandas as pd
import numpy as np
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go

# %%
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
# %matplotlib inline

# %%
dataframe = pd.DataFrame(np.random.randn(100, 4), columns=['a', 'b', 'c', 'd'])
#creamos el dataframe con 100 filas y 4 columnas

# %%
dataframe
#mostramos el dataframe
# Out:
#            a         b         c         d
# 0  -0.768363  0.251778  1.711369 -0.585484
# 1  -0.560853 -0.666877 -1.570303  0.593795
# 2   0.084503 -0.901019 -1.104182 -0.244581
# 3   0.587813 -2.145043 -0.078440 -0.353605
# 4  -1.024315  0.105180 -0.219894 -0.919056
# ..       ...       ...       ...       ...
# 95  0.997779 -0.502351 -0.368471 -1.151732
# 96  0.466342  2.194878 -0.060186  0.240280
# 97  1.604637 -0.206306 -0.116029  0.652013
# 98 -0.416061 -0.744356  0.994474 -1.553175
# 99 -0.789050 -0.894421 -0.182256  0.085806
#
# [100 rows x 4 columns]

# %%
dataframe.plot()
#mostramos el grafico de las 4 columnas
# Out:
# <Axes: >
